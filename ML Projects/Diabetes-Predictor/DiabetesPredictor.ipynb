# %%
#for data analysis
import numpy as np
import pandas as pd

# %%
#for data visualisation
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#Reading data
test_df = pd.read_csv("/workspaces/DSProjects/Diabetes-Predictor/diabetes.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspaces/DSProjects/Diabetes-Predictor/DiabetesPredictor.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://codespaces%2Bfluffy-space-goldfish-vw44gqv9r7g2r4q/workspaces/DSProjects/Diabetes-Predictor/DiabetesPredictor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> #Reading data
# ----> <a href='vscode-notebook-cell://codespaces%2Bfluffy-space-goldfish-vw44gqv9r7g2r4q/workspaces/DSProjects/Diabetes-Predictor/DiabetesPredictor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> test_df = pd.read_csv("/workspaces/DSProjects/Diabetes-Predictor/diabetes.csv")
#
# NameError: name 'pd' is not defined
